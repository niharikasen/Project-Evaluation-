# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"C:\Users\HP\Documents\HR.csv")
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.tail()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS(EDA)

# %%
#checking dimension of data set
df.shape
# Out:
# (1470, 35)

# %% [markdown]
# ###### this data set contain 1470 rows and 35 columns.out of which 1 is target variable and remaining 34 is independent variables.

# %%
#checking column details  of data set
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df[df.duplicated(keep='first')].shape
# Out:
# (0, 35)

# %% [markdown]
# ###### there is no duplicate rows

# %%
# list of column
df.columns.tolist()
# Out:
# ['Age',
#  'Attrition',
#  'BusinessTravel',
#  'DailyRate',
#  'Department',
#  'DistanceFromHome',
#  'Education',
#  'EducationField',
#  'EmployeeCount',
#  'EmployeeNumber',
#  'EnvironmentSatisfaction',
#  'Gender',
#  'HourlyRate',
#  'JobInvolvement',
#  'JobLevel',
#  'JobRole',
#  'JobSatisfaction',
#  'MaritalStatus',
#  'MonthlyIncome',
#  'MonthlyRate',
#  'NumCompaniesWorked',
#  'Over18',
#  'OverTime',
#  'PercentSalaryHike',
#  'PerformanceRating',
#  'RelationshipSatisfaction',
#  'StandardHours',
#  'StockOptionLevel',
#  'TotalWorkingYears',
#  'TrainingTimesLastYear',
#  'WorkLifeBalance',
#  'YearsAtCompany',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager']

# %%
#checking data types of column
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %% [markdown]
# ###### there are two different type of data present in data set (object,int64)

# %%
# checking nun values if any value is present
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# ###### there is no null value present in any column

# %%
# using  visualize techinque  heatmap 
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# ###### There is no missing data present

# %%
# we check unique value in quality collumn 
df['Attrition'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['Attrition'].nunique()
# Out:
# 2

# %%
# checking the value counts of each columns
for i in df.columns:
    print(df[i].value_counts())
    print("\n")
# Out:
# 35    78
# 34    77
# 36    69
# 31    69
# 29    68
# 32    61
# 30    60
# 33    58
# 38    58
# 40    57
# 37    50
# 27    48
# 28    48
# 42    46
# 39    42
# 45    41
# 41    40
# 26    39
# 44    33
# 46    33
# 43    32
# 50    30
# 25    26
# 24    26
# 49    24
# 47    24
# 55    22
# 51    19
# 53    19
# 48    19
# 54    18
# 52    18
# 22    16
# 56    14
# 23    14
# 58    14
# 21    13
# 20    11
# 59    10
# 19     9
# 18     8
# 60     5
# 57     4
# Name: Age, dtype: int64
#
#
# No     1233
# Yes     237
# Name: Attrition, dtype: int64
#
#
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64
#
#
# 691     6
# 408     5
# 530     5
# 1329    5
# 1082    5
#        ..
# 650     1
# 279     1
# 316     1
# 314     1
# 628     1
# Name: DailyRate, Length: 886, dtype: int64
#
#
# Research & Development    961
# Sales                     446
# Human Resources            63
# ...

# %% [markdown]
# # Description of Data set

# %%
# used describe method its give information about the continuous column
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# ###### The summary of data set look perfect sinces there is no negative values and invalid values present.
# from above the description we can observer the following.
# ######
# 1) The count of all the columns are same  which means there are no missing values present in the data set.
# 2)The difference between mean value and std value is high means data distribution is correct.
#
# 3) In  first quartile(25%)and second quratile(50%) not much of variance.
# 4) In the  data we can observe there is huge difference in (75%) and max column in column .Hence there are outlier present in the data.
# 5)   we observe the data is uniformly distributed.

# %% [markdown]
# # Data visualization

# %% [markdown]
# # Countplot

# %%
sns.countplot(x='Attrition', data=df)
# Out:
# <Axes: xlabel='Attrition', ylabel='count'>

# %%
sns.countplot(x = 'Department', data=df)
# Out:
# <Axes: xlabel='Department', ylabel='count'>

# %% [markdown]
# ###### Sales department and Human resources department are having higher attrition rate compared to research and development department.

# %%
 sns.countplot(x='EducationField', data=df)
# Out:
# <Axes: xlabel='EducationField', ylabel='count'>

# %%
 sns.countplot(x='Age', data=df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(x='MaritalStatus', data=df)
# Out:
# <Axes: xlabel='MaritalStatus', ylabel='count'>

# %% [markdown]
# # Boxplot

# %%
sns.boxplot(x = 'Attrition', y='Age', data=df)
# Out:
# <Axes: xlabel='Attrition', ylabel='Age'>

# %%
sns.boxplot(x = 'Attrition', y='WorkLifeBalance', data=df)
# Out:
# <Axes: xlabel='Attrition', ylabel='WorkLifeBalance'>

# %% [markdown]
# ###### single peopel are more likely to quit compared to married and divorced people.

# %% [markdown]
# # Histrogram

# %%
df.hist(figsize =(10,10),bins=50)
plt.show()

# %% [markdown]
# # Corrleation Between Target Variable And Independent Variable

# %%
cor =df.corr()
cor
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.010661         -0.001686   0.208034
# DailyRate                 0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome         -0.001686  -0.004985          1.000000   0.021042
# Education                 0.208034  -0.016806          0.021042   1.000000
# EmployeeCount                  NaN        NaN               NaN        NaN
# EmployeeNumber           -0.010145  -0.050990          0.032916   0.042070
# EnvironmentSatisfaction   0.010146   0.018355         -0.016075  -0.027128
# HourlyRate                0.024287   0.023381          0.031131   0.016775
# JobInvolvement            0.029820   0.046135          0.008783   0.042438
# JobLevel                  0.509604   0.002966          0.005303   0.101589
# JobSatisfaction          -0.004892   0.030571         -0.003669  -0.011296
# ...

# %% [markdown]
# # Heatmap

# %%
plt.figure(figsize = (20,15))
sns.heatmap(df.corr(),linewidths = 0.1,fmt = ".1g", linecolor="black",annot = True)
plt.yticks(rotation =0);
plt.show()

# %% [markdown]
# ###### From the correlation table we see that monthly income is highly correlated with job level. However, daily rate, hourly rate and monthly rate are barely correlated with anything. We will be using monthly income in later analysis as a measurement of salary and get rid of other income related variables.

# %% [markdown]
# # Drop unnecessary column

# %%
df.drop(['DailyRate', 'HourlyRate', 'MonthlyRate'], axis = 1, inplace = True)

# %%
df.drop(['EmployeeNumber'], axis = 1, inplace = True)

# %%
temp = []
for col in df.columns:
    if len(df[col].unique()) == 1:
        temp.append(col)
        df.drop(col,inplace=True,axis=1)

# %%
temp
# Out:
# ['EmployeeCount', 'Over18', 'StandardHours']

# %%
df['Male'] = df.Gender == 'Male'

# %%
df.drop('Gender', axis = 1,inplace=True)

# %%
df['OverTime'] = df.OverTime == 'Yes'

# %%
df['Attrition'] = df.Attrition == 'Yes'

# %% [markdown]
# # Create Dummies

# %%
df1 = pd.get_dummies(df, columns=['BusinessTravel','Department',
                        'EducationField','JobRole','MaritalStatus'])

# %%
df1.head()
# Out:
#    Age  Attrition  DistanceFromHome  Education  EnvironmentSatisfaction  \
# 0   41       True                 1          2                        2
# 1   49      False                 8          1                        3
# 2   37       True                 2          2                        4
# 3   33      False                 3          4                        4
# 4   27      False                 2          1                        1
#
#    JobInvolvement  JobLevel  JobSatisfaction  MonthlyIncome  \
# 0               3         2                4           5993
# 1               2         2                2           5130
# 2               2         1                3           2090
# 3               3         1                3           2909
# 4               3         1                2           3468
#
#    NumCompaniesWorked  ...  JobRole_Laboratory Technician  JobRole_Manager  \
# 0                   8  ...                              0                0
# ...

# %% [markdown]
# # Separating features and label

# %%
x = df1.drop('Attrition',axis=1)
y = df1.Attrition

# %%
print("independent variable")
x
# Out:
# independent variable
#       Age  DistanceFromHome  Education  EnvironmentSatisfaction  \
# 0      41                 1          2                        2
# 1      49                 8          1                        3
# 2      37                 2          2                        4
# 3      33                 3          4                        4
# 4      27                 2          1                        1
# ...   ...               ...        ...                      ...
# 1465   36                23          2                        3
# 1466   39                 6          1                        4
# 1467   27                 4          3                        2
# 1468   49                 2          3                        4
# 1469   34                 8          3                        2
#
#       JobInvolvement  JobLevel  JobSatisfaction  MonthlyIncome  \
# 0                  3         2                4           5993
# ...

# %%
print("dependent variable")
y
# Out:
# dependent variable
# 0        True
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 1465    False
# 1466    False
# 1467    False
# 1468    False
# 1469    False
# Name: Attrition, Length: 1470, dtype: bool

# %% [markdown]
# # Feature Scaling Using Standard Scalarization

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x = pd.DataFrame(scaler.fit_transform(x),columns = x.columns)
print(x)
# Out:
#            Age  DistanceFromHome  Education  EnvironmentSatisfaction  \
# 0     0.446350         -1.010909  -0.891688                -0.660531
# 1     1.322365         -0.147150  -1.868426                 0.254625
# 2     0.008343         -0.887515  -0.891688                 1.169781
# 3    -0.429664         -0.764121   1.061787                 1.169781
# 4    -1.086676         -0.887515  -1.868426                -1.575686
# ...        ...               ...        ...                      ...
# 1465 -0.101159          1.703764  -0.891688                 0.254625
# 1466  0.227347         -0.393938  -1.868426                 1.169781
# 1467 -1.086676         -0.640727   0.085049                -0.660531
# 1468  1.322365         -0.887515   0.085049                 1.169781
# 1469 -0.320163         -0.147150   0.085049                -0.660531
#
#       JobInvolvement  JobLevel  JobSatisfaction  MonthlyIncome  \
# 0           0.379672 -0.057788         1.153254      -0.108350
# ...

# %% [markdown]
# # Variance Information Factor(VIF)

# %%
from statsmodels.stats.outliers_influence import  variance_inflation_factor
vif =pd.DataFrame()
vif["VIF value"] = [variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif["features"] = x.columns
vif
# Out:
#     VIF value                           features
# 0    2.081066                                Age
# 1    1.020718                   DistanceFromHome
# 2    1.082406                          Education
# 3    1.025774            EnvironmentSatisfaction
# 4    1.029173                     JobInvolvement
# 5   14.101549                           JobLevel
# 6    1.018428                    JobSatisfaction
# 7   18.075977                      MonthlyIncome
# 8    1.281669                 NumCompaniesWorked
# 9    1.034403                           OverTime
# 10   2.561676                  PercentSalaryHike
# 11   2.548819                  PerformanceRating
# 12   1.027277           RelationshipSatisfaction
# 13   1.908279                   StockOptionLevel
# 14   5.005134                  TotalWorkingYears
# 15   1.036585              TrainingTimesLastYear
# 16   1.027616                    WorkLifeBalance
# 17   4.738400                     YearsAtCompany
# ...

# %% [markdown]
# ###### we obsereve that MonthlyIncome and job_level column have multicolinearity issue.

# %% [markdown]
# # Oversampling

# %%
# !pip install imblearn
from imblearn.over_sampling import SMOTE
SM =SMOTE()
x1,y1 = SM.fit_resample(x,y)

# %%
# we check target variable 
y.value_counts()
# Out:
# False    1233
# True      237
# Name: Attrition, dtype: int64

# %% [markdown]
# # Modelling

# %% [markdown]
# # Finding the best random state

# %%
from sklearn.model_selection import train_test_split
from  sklearn.ensemble import RandomForestClassifier
from sklearn .metrics import accuracy_score
maxAccu = 0
maxRS =0
for i in range (1,2):
    x_train, x_test,y_train ,y_test = train_test_split(x1 , y1, test_size =0.30,random_state =i)
    RFR = RandomForestClassifier()
    RFR.fit(x_train, y_train)
    pred =RFR.predict(x_test)
    acc = accuracy_score(y_test,pred)
    if acc>maxAccu:
        maxAcc = acc
        maxRS= i
    print("Best accuracy is",maxAccu,"at random_state",maxRS)
# Out:
# Best accuracy is 0 at random_state 1

# %%
x_train, x_test,y_train ,y_test = train_test_split(x1 , y1, test_size =0.30,random_state =maxRS)

# %% [markdown]
# # Classification Alogithrms

# %%
from  sklearn.ensemble import RandomForestClassifier,ExtraTreesClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from  sklearn.ensemble import GradientBoostingClassifier,AdaBoostClassifier,BaggingClassifier
from sklearn.metrics import classification_report, confusion_matrix, roc_curve ,accuracy_score
from sklearn.model_selection import cross_val_score

# %% [markdown]
# # Random Forest Classifier

# %%
RFC = RandomForestClassifier()
RFC.fit(x_train,y_train)
predRFC = RFC.predict(x_test)
print(accuracy_score (y_test,predRFC))
print (confusion_matrix(y_test,predRFC))
print (classification_report(y_test,predRFC))
# Out:
# 0.9202702702702703
# [[338   8]
#  [ 51 343]]
#               precision    recall  f1-score   support
#
#        False       0.87      0.98      0.92       346
#         True       0.98      0.87      0.92       394
#
#     accuracy                           0.92       740
#    macro avg       0.92      0.92      0.92       740
# weighted avg       0.93      0.92      0.92       740

# %% [markdown]
# ###### The accuracy of Random forest model is 92%

# %% [markdown]
# # Logistic Regression

# %%
LR = LogisticRegression()
LR.fit(x_train,y_train)
predLR = LR.predict(x_test)
print(accuracy_score (y_test,predLR))
print (confusion_matrix(y_test,predLR))
print (classification_report(y_test,predLR))
# Out:
# 0.7986486486486486
# [[267  79]
#  [ 70 324]]
#               precision    recall  f1-score   support
#
#        False       0.79      0.77      0.78       346
#         True       0.80      0.82      0.81       394
#
#     accuracy                           0.80       740
#    macro avg       0.80      0.80      0.80       740
# weighted avg       0.80      0.80      0.80       740

# %% [markdown]
# ###### The accuracy of logistic regression model is 80%

# %% [markdown]
# # Support Vector Machine Classifier

# %%
svc= SVC()
svc.fit(x_train,y_train)
predsvc = svc.predict(x_test)
print(accuracy_score (y_test,predsvc))
print (confusion_matrix(y_test,predsvc))
print (classification_report(y_test,predsvc))
# Out:
# 0.9108108108108108
# [[307  39]
#  [ 27 367]]
#               precision    recall  f1-score   support
#
#        False       0.92      0.89      0.90       346
#         True       0.90      0.93      0.92       394
#
#     accuracy                           0.91       740
#    macro avg       0.91      0.91      0.91       740
# weighted avg       0.91      0.91      0.91       740

# %% [markdown]
# ###### The accuracy of support vector machine classifier model is 91%

# %% [markdown]
# # Gradient Boosting Classifier

# %%
GB= GradientBoostingClassifier()
GB.fit(x_train,y_train)
predGB = GB.predict(x_test)
print(accuracy_score (y_test,predGB))
print (confusion_matrix(y_test,predGB))
print (classification_report(y_test,predGB))
# Out:
# 0.9067567567567567
# [[332  14]
#  [ 55 339]]
#               precision    recall  f1-score   support
#
#        False       0.86      0.96      0.91       346
#         True       0.96      0.86      0.91       394
#
#     accuracy                           0.91       740
#    macro avg       0.91      0.91      0.91       740
# weighted avg       0.91      0.91      0.91       740

# %% [markdown]
# ###### The accuracy of Gradient Boosting Classifier is 91%

# %% [markdown]
# # Ada Boost Classifier

# %%
ABC= AdaBoostClassifier()
ABC.fit(x_train,y_train)
predABC = ABC.predict(x_test)
print(accuracy_score (y_test,predABC))
print (confusion_matrix(y_test,predABC))
print (classification_report(y_test,predABC))
# Out:
# 0.8986486486486487
# [[315  31]
#  [ 44 350]]
#               precision    recall  f1-score   support
#
#        False       0.88      0.91      0.89       346
#         True       0.92      0.89      0.90       394
#
#     accuracy                           0.90       740
#    macro avg       0.90      0.90      0.90       740
# weighted avg       0.90      0.90      0.90       740

# %% [markdown]
# ###### The accuracy of Ada Boost Classifier is 89%

# %% [markdown]
# # BaggingClassifier

# %%
BC= BaggingClassifier()
BC.fit(x_train,y_train)
predBC = BC.predict(x_test)
print(accuracy_score (y_test,predBC))
print (confusion_matrix(y_test,predBC))
print (classification_report(y_test,predBC))
# Out:
# 0.8837837837837837
# [[326  20]
#  [ 66 328]]
#               precision    recall  f1-score   support
#
#        False       0.83      0.94      0.88       346
#         True       0.94      0.83      0.88       394
#
#     accuracy                           0.88       740
#    macro avg       0.89      0.89      0.88       740
# weighted avg       0.89      0.88      0.88       740

# %% [markdown]
# ###### The accuracy of Bagging Classifier is 88%

# %% [markdown]
# # Extra Trees Classifier

# %%
ET = ExtraTreesClassifier()
ET.fit(x_train,y_train)
predET = ET.predict(x_test)
print(accuracy_score (y_test,predET))
print (confusion_matrix(y_test,predET))
print (classification_report(y_test,predET))
# Out:
# 0.9513513513513514
# [[334  12]
#  [ 24 370]]
#               precision    recall  f1-score   support
#
#        False       0.93      0.97      0.95       346
#         True       0.97      0.94      0.95       394
#
#     accuracy                           0.95       740
#    macro avg       0.95      0.95      0.95       740
# weighted avg       0.95      0.95      0.95       740

# %% [markdown]
# ###### The accuracy of ExtraTreesClassifier is 95%

# %% [markdown]
# # Cross Validation Score

# %%
from sklearn.model_selection import cross_val_score

# %%
# checking crosss validation score for random forest classifier
score = cross_val_score(RFC,x1,y1)
print(score)
print(score.mean())
print("Difference Between Accuracy and Cross Validation Score is_",accuracy_score(y_test,predRFC)-score.mean())
# Out:
# [0.7611336  0.98377282 0.97971602 0.98174442 0.97971602]
# 0.9372165786599437
# Difference Between Accuracy and Cross Validation Score is_ -0.01694630838967337

# %%
# checking crosss validation score for Logistic Regression
score = cross_val_score(LR,x1,y1)
print(score)
print(score.mean())
print("Difference Between Accuracy and Cross Validation Score is_",accuracy_score(y_test,predLR)-score.mean())
# Out:
# [0.79149798 0.82150101 0.81135903 0.77687627 0.81541582]
# 0.8033300211051893
# Difference Between Accuracy and Cross Validation Score is_ -0.004681372456540656

# %%
# checking crosss validation score for support vector machine classifier
score = cross_val_score(svc,x1,y1)
print(score)
print(score.mean())
print("Difference Between Accuracy and Cross Validation Score is_",accuracy_score(y_test,predsvc)-score.mean())
# Out:
# [0.90688259 0.93711968 0.9148073  0.92494929 0.9127789 ]
# 0.9193075527013821
# Difference Between Accuracy and Cross Validation Score is_ -0.008496741890571258

# %%
# checking crosss validation score for Ada Boost Classifier
score = cross_val_score(ABC,x1,y1)
print(score)
print(score.mean())
print("Difference Between Accuracy and Cross Validation Score is_",accuracy_score(y_test,predABC)-score.mean())
# Out:
# [0.6417004  0.94726166 0.92900609 0.90669371 0.94320487]
# 0.8735733466917411
# Difference Between Accuracy and Cross Validation Score is_ 0.025075301956907547

# %%
# checking crosss validation score for Bagging Classifier
score = cross_val_score(BC,x1,y1)
print(score)
print(score.mean())
print("Difference Between Accuracy and Cross Validation Score is_",accuracy_score(y_test,predBC)-score.mean())
# Out:
# [0.7145749  0.94929006 0.95131846 0.94929006 0.96551724]
# 0.9059981440572878
# Difference Between Accuracy and Cross Validation Score is_ -0.022214360273504097

# %%
# checking crosss validation score for GradientBoosting Classifier
score = cross_val_score(GB,x1,y1)
print(score)
print(score.mean())
print("Difference Between Accuracy and Cross Validation Score is_",accuracy_score(y_test,predGB)-score.mean())
# Out:
# [0.56072874 0.97363083 0.96348884 0.95943205 0.97363083]
# 0.8861822601440409
# Difference Between Accuracy and Cross Validation Score is_ 0.02057449661271582

# %%
# checking crosss validation score for Extra Trees Classifier
score = cross_val_score(ET,x1,y1)
print(score)
print(score.mean())
print("Difference Between Accuracy and Cross Validation Score is_",accuracy_score(y_test,predET)-score.mean())
# Out:
# [0.92105263 0.97565923 0.98377282 0.97565923 0.97160243]
# 0.9655492687092986
# Difference Between Accuracy and Cross Validation Score is_ -0.014197917357947176

# %% [markdown]
# ###### The random forest classifier and Extra Trees classifier give us good accuracy

# %% [markdown]
# ###### Extra tree classifier model is best model with 96% accuracy

# %% [markdown]
# # Hyper Parameter Tuning

# %%
from sklearn.model_selection import GridSearchCV
parameters = {'criterion':['gini','entropy'],
               'random_state':[10,50,100],
             'max_depth':[0,10,20],
             'n_jobs':[-2,-1,-1],
             'n_estimators':[25,50,100,200]}

# %%
GCV =GridSearchCV(ExtraTreesClassifier(),parameters,cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=ExtraTreesClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [0, 10, 20],
#                          'n_estimators': [25, 50, 100, 200],
#                          'n_jobs': [-2, -1, -1],
#                          'random_state': [10, 50, 100]})

# %%
GCV.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 20,
#  'n_estimators': 100,
#  'n_jobs': -2,
#  'random_state': 50}

# %%
Final_model = ExtraTreesClassifier(criterion ='entropy', max_depth =20, n_estimators=100,n_jobs =-2,random_state= 50)
Final_model.fit(x_train,y_train)
pred = Final_model.predict(x_test)
print (acc*100)
# Out:
# 92.43243243243244

# %% [markdown]
# # Plotting Roc and Auc Curve

# %%
from sklearn import metrics
fpr,tpr,threshold = metrics.roc_curve(y_test,pred)
roc_auc = metrics.auc(fpr,tpr)
display = metrics.RocCurveDisplay(fpr =fpr,tpr =tpr,roc_auc=roc_auc,estimator_name =Final_model)
display.plot()

# %% [markdown]
# ###### We Have plot Roc Curve For The Final Model And The Auc Value For The Best Model Is 92%

# %% [markdown]
# # Saving The Model

# %%
import joblib
joblib.dump(Final_model,"HR Analytics Project.pkl")
# Out:
# ['HR Analytics Project.pkl']

# %% [markdown]
# # Predicting The Save Model

# %%
# lets load the save model and predict it 
model =joblib.load("HR Analytics Project.pkl")
prediction = model.predict(x_test)
prediction
# Out:
# array([False,  True, False,  True,  True, False,  True, False,  True,
#         True,  True,  True,  True, False, False,  True,  True, False,
#         True, False, False, False, False,  True, False,  True, False,
#        False, False, False,  True, False, False,  True, False,  True,
#        False, False, False, False,  True,  True,  True,  True,  True,
#        False,  True,  True, False, False,  True, False, False, False,
#         True,  True, False, False, False, False,  True,  True,  True,
#         True,  True,  True,  True,  True, False, False,  True, False,
#        False,  True,  True,  True, False,  True,  True,  True, False,
#        False, False, False,  True, False, False, False,  True,  True,
#        False, False, False,  True, False,  True,  True,  True, False,
#         True, False, False,  True,  True, False, False, False, False,
#         True, False,  True,  True,  True, False,  True, False,  True,
# ...

# %%
a = np.array(y_test)
df = pd.DataFrame()
df["predicted"] = prediction
df["original"] = a
df
# Out:
#      predicted  original
# 0        False     False
# 1         True      True
# 2        False     False
# 3         True      True
# 4         True      True
# ..         ...       ...
# 735       True      True
# 736       True      True
# 737       True      True
# 738       True     False
# 739       True      True
#
# [740 rows x 2 columns]

# %% [markdown]
# ###### Here the original value and predicted value is same means prediction is correct and if it is not same then prediction is wrong.

# %% [markdown]
# # project Description

# %% [markdown]
# ######  1.In this data set first   we import libaries and then perform EdA part
#
# 2.check null values and plot headmap that give idea for null value present or not
#
# 3.performing both statistical and data visualization techinque.
#
# 4.check correlation and plot headmap
#
# 5.delete unnecessary column and create dummies
#
# 6.select features and label
#
# 7.Features selection
#
#
# 8.data standarization and normalization
#
# 9.creation of train and test data set using algorithm parameters
#
# 10.variance inflation factor  checking multicolinearity  issues.
#
# 11.oversamping technique used.
#
# 12.model training using machine learning algorithm
#
#
# 13.calculation of model accuracy both training and test accuracy and used cross validation .
#
# 14.select best model and perform hyperparameter tunning to  a better accuracy
#
# 15. plot Roc/AUC curve.
#
# 16.saving the created model file.
